# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: contourpy==1.3.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: cycler==0.12.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools==4.53.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (4.53.1)
# Requirement already satisfied: kiwisolver==1.4.7 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: matplotlib==3.9.2 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (3.9.2)
# Requirement already satisfied: numpy==2.1.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (2.1.1)
# Requirement already satisfied: packaging==24.1 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (24.1)
# Requirement already satisfied: pillow==10.4.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (10.4.0)
# Requirement already satisfied: pygame==2.6.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (2.6.0)
# Requirement already satisfied: pyparsing==3.1.4 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (3.1.4)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (2.9.0.post0)
# Requirement already satisfied: six==1.16.0 in ./venv/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (1.16.0)

# %%
# %load_ext autoreload
# %autoreload 2
from cls import *
import time

# %%
from cls import *
import time
BOARDSIZE = 60
NUM_CLUSTERS = 3
PROB_NURSE = 0.05
PROB_PERSON = 0.3
sim = Simulation(board_size=BOARDSIZE,num_clusters=NUM_CLUSTERS,
                    prob_nurse=PROB_NURSE,prob_person=PROB_PERSON)
sim.start()
sim.view()
# Out:
# Infecting 3

# %%
sim.run_to_end()
# Out:
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554D3A810>] [<cls.Disease object at 0x0000020554D3A810>]
# <cls.Disease object at 0x0000020554D3A810> added to 14 14
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554D5AB90>] [<cls.Disease object at 0x0000020554D5AB90>]
# [<cls.Disease object at 0x0000020554D5AB90>]
# <cls.Disease object at 0x0000020554D5AB90> added to 16 5
# Adding from [<cls.Disease object at 0x0000020554D5AB90>] [<cls.Disease object at 0x0000020554D5AB90>]
# <cls.Disease object at 0x0000020554D5AB90> added to 17 4
# Health decreased
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554D5AB90>] [<cls.Disease object at 0x0000020554D5AB90>]
# [<cls.Disease object at 0x0000020554D5AB90>]
# <cls.Disease object at 0x0000020554D5AB90> added to 13 7
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554D580D0>] [<cls.Disease object at 0x0000020554D580D0>]
# <cls.Disease object at 0x0000020554D580D0> added to 9 14
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554D5AB90>] [<cls.Disease object at 0x0000020554D5AB90>]
# [<cls.Disease object at 0x0000020554D5AB90>]
# <cls.Disease object at 0x0000020554D5AB90> added to 13 6
# Health decreased
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554D5AB90>] [<cls.Disease object at 0x0000020554D5AB90>]
# [<cls.Disease object at 0x0000020554D5AB90>]
# <cls.Disease object at 0x0000020554D5AB90> added to 17 6
# Health decreased
# Node health is 3
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554DB60D0>] [<cls.Disease object at 0x0000020554DB60D0>]
# [<cls.Disease object at 0x0000020554DB60D0>]
# <cls.Disease object at 0x0000020554DB60D0> added to 13 6
# Adding from [<cls.Disease object at 0x0000020554DB60D0>] [<cls.Disease object at 0x0000020554DB60D0>]
# <cls.Disease object at 0x0000020554DB60D0> added to 13 8
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554DB60D0>] [<cls.Disease object at 0x0000020554DB60D0>]
# <cls.Disease object at 0x0000020554DB60D0> added to 16 2
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554DB60D0>] [<cls.Disease object at 0x0000020554DB60D0>]
# [<cls.Disease object at 0x0000020554DB60D0>]
# <cls.Disease object at 0x0000020554DB60D0> added to 16 2
# Health decreased
# Node health is 2
# Health decreased
# Node health is 4
# Health decreased
# Node health is 1
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554E3B410>] [<cls.Disease object at 0x0000020554E3B410>]
# <cls.Disease object at 0x0000020554E3B410> added to 7 14
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554DB60D0>] [<cls.Disease object at 0x0000020554DB60D0>]
# [<cls.Disease object at 0x0000020554DB60D0>]
# <cls.Disease object at 0x0000020554DB60D0> added to 13 7
# Adding from [<cls.Disease object at 0x0000020554DB60D0>] [<cls.Disease object at 0x0000020554DB60D0>]
# [<cls.Disease object at 0x0000020554DB60D0>]
# <cls.Disease object at 0x0000020554DB60D0> added to 14 6
# Node health is 6
# Health decreased
# Node health is 2
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554CD0390>] [<cls.Disease object at 0x0000020554CD0390>]
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554CD0390>] [<cls.Disease object at 0x0000020554CD0390>]
# <cls.Disease object at 0x0000020554CD0390> added to 11 6
# Adding from [<cls.Disease object at 0x0000020554CD0390>] [<cls.Disease object at 0x0000020554CD0390>]
# Adding from [<cls.Disease object at 0x0000020554CD0390>] [<cls.Disease object at 0x0000020554CD0390>]
# Health decreased
# Node health is 3
# Node health is 4
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554CBA390>] [<cls.Disease object at 0x0000020554CBA390>]
# [<cls.Disease object at 0x0000020554CBA390>]
# <cls.Disease object at 0x0000020554CBA390> added to 8 14
# Adding from [<cls.Disease object at 0x0000020554CBA390>] [<cls.Disease object at 0x0000020554CBA390>]
# <cls.Disease object at 0x0000020554CBA390> added to 10 16
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554CD0390>] [<cls.Disease object at 0x0000020554CD0390>]
# [<cls.Disease object at 0x0000020554CD0390>]
# <cls.Disease object at 0x0000020554CD0390> added to 13 8
# Adding from [<cls.Disease object at 0x0000020554CD0390>] [<cls.Disease object at 0x0000020554CD0390>]
# [<cls.Disease object at 0x0000020554CD0390>]
# <cls.Disease object at 0x0000020554CD0390> added to 14 6
# Health decreased
# Node health is 3
# Node health is 2
# Health decreased
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554cls310>] [<cls.Disease object at 0x0000020554cls310>]
# [<cls.Disease object at 0x0000020554CBA390>]
# <cls.Disease object at 0x0000020554cls310> added to 12 12
# Adding from [<cls.Disease object at 0x0000020554cls310>] [<cls.Disease object at 0x0000020554cls310>]
# [<cls.Disease object at 0x0000020554cls310>]
# <cls.Disease object at 0x0000020554cls310> added to 13 14
# Node health is 1
# Health decreased
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554cls310>] [<cls.Disease object at 0x0000020554cls310>]
# <cls.Disease object at 0x0000020554cls310> added to 12 15
# Adding from [<cls.Disease object at 0x0000020554cls310>] [<cls.Disease object at 0x0000020554cls310>]
# [<cls.Disease object at 0x0000020554cls310>]
# <cls.Disease object at 0x0000020554cls310> added to 14 14
# Health decreased
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554CD0390>] [<cls.Disease object at 0x0000020554CD0390>]
# Adding from [<cls.Disease object at 0x0000020554CD0390>] [<cls.Disease object at 0x0000020554CD0390>]
# <cls.Disease object at 0x0000020554CD0390> added to 13 9
# Adding from [<cls.Disease object at 0x0000020554CD0390>] [<cls.Disease object at 0x0000020554CD0390>]
# [<cls.Disease object at 0x0000020554CD0390>]
# <cls.Disease object at 0x0000020554CD0390> added to 14 8
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554CD0390>] [<cls.Disease object at 0x0000020554CD0390>]
# [<cls.Disease object at 0x0000020554CD0390>]
# <cls.Disease object at 0x0000020554CD0390> added to 17 3
# Node health is 6
# Health decreased
# Node health is 3
# Node health is 2
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554D07250>] [<cls.Disease object at 0x0000020554D07250>]
# <cls.Disease object at 0x0000020554D07250> added to 12 10
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554DF7610>] [<cls.Disease object at 0x0000020554DF7610>]
# [<cls.Disease object at 0x0000020554DF7610>]
# <cls.Disease object at 0x0000020554DF7610> added to 13 7
# Adding from [<cls.Disease object at 0x0000020554DF7610>] [<cls.Disease object at 0x0000020554DF7610>]
# [<cls.Disease object at 0x0000020554DF7610>]
# <cls.Disease object at 0x0000020554DF7610> added to 13 9
# Adding from [<cls.Disease object at 0x0000020554DF7610>] [<cls.Disease object at 0x0000020554DF7610>]
# [<cls.Disease object at 0x0000020554DF7610>]
# <cls.Disease object at 0x0000020554DF7610> added to 14 9
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554DF7610>] [<cls.Disease object at 0x0000020554DF7610>]
# <cls.Disease object at 0x0000020554DF7610> added to 10 7
# Adding from [<cls.Disease object at 0x0000020554DF7610>] [<cls.Disease object at 0x0000020554DF7610>]
# [<cls.Disease object at 0x0000020554DF7610>]
# <cls.Disease object at 0x0000020554DF7610> added to 11 6
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554DF7610>] [<cls.Disease object at 0x0000020554DF7610>]
# [<cls.Disease object at 0x0000020554DF7610>]
# <cls.Disease object at 0x0000020554DF7610> added to 16 3
# Node health is 3
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554DF7610>] [<cls.Disease object at 0x0000020554DF7610>]
# [<cls.Disease object at 0x0000020554DF7610>]
# <cls.Disease object at 0x0000020554DF7610> added to 13 8
# Adding from [<cls.Disease object at 0x0000020554DF7610>] [<cls.Disease object at 0x0000020554DF7610>]
# [<cls.Disease object at 0x0000020554DF7610>]
# <cls.Disease object at 0x0000020554DF7610> added to 13 9
# Health decreased
# Node health is 6
# Adding from [<cls.Disease object at 0x0000020554CBE490>] [<cls.Disease object at 0x0000020554CBE490>]
# Adding from [<cls.Disease object at 0x0000020554CBE490>] [<cls.Disease object at 0x0000020554CBE490>]
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554CBE490>] [<cls.Disease object at 0x0000020554CBE490>]
# [<cls.Disease object at 0x0000020554D07250>]
# <cls.Disease object at 0x0000020554CBE490> added to 11 15
# Node health is 1
# Health decreased
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554DF7610>] [<cls.Disease object at 0x0000020554DF7610>]
# [<cls.Disease object at 0x0000020554DF7610>]
# <cls.Disease object at 0x0000020554DF7610> added to 13 8
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554DF7610>] [<cls.Disease object at 0x0000020554DF7610>]
# [<cls.Disease object at 0x0000020554DF7610>]
# <cls.Disease object at 0x0000020554DF7610> added to 13 8
# Health decreased
# Node health is 3
# Health decreased
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554D07250>] [<cls.Disease object at 0x0000020554D07250>]
# [<cls.Disease object at 0x0000020554CBE490>]
# <cls.Disease object at 0x0000020554D07250> added to 11 14
# Adding from [<cls.Disease object at 0x0000020554D07250>] [<cls.Disease object at 0x0000020554D07250>]
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554D07250>] [<cls.Disease object at 0x0000020554D07250>]
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554DFBA50>] [<cls.Disease object at 0x0000020554DFBA50>]
# [<cls.Disease object at 0x0000020554E197D0>]
# <cls.Disease object at 0x0000020554DFBA50> added to 11 9
# Adding from [<cls.Disease object at 0x0000020554DFBA50>] [<cls.Disease object at 0x0000020554DFBA50>]
# [<cls.Disease object at 0x0000020554DFBA50>]
# <cls.Disease object at 0x0000020554DFBA50> added to 13 8
# Node health is 2
# Node health is 0
# Node died
# Node health is 7
# Adding from [<cls.Disease object at 0x0000020554DFBA50>] [<cls.Disease object at 0x0000020554DFBA50>]
# <cls.Disease object at 0x0000020554DFBA50> added to 8 6
# Health decreased
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554E197D0>] [<cls.Disease object at 0x0000020554E197D0>]
# Adding from [<cls.Disease object at 0x0000020554E197D0>] [<cls.Disease object at 0x0000020554E197D0>]
# [<cls.Disease object at 0x0000020554DFBB10>]
# <cls.Disease object at 0x0000020554E197D0> added to 12 16
# Node health is 6
# Adding from [<cls.Disease object at 0x0000020554E197D0>] [<cls.Disease object at 0x0000020554E197D0>]
# Node health is 3
# Node health is 3
# Node health is 5
# Node health is 0
# Node died
# Health decreased
# Node health is 1
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554DFBA50>] [<cls.Disease object at 0x0000020554DFBA50>]
# [<cls.Disease object at 0x0000020554DFBA50>]
# <cls.Disease object at 0x0000020554DFBA50> added to 17 2
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554E197D0>] [<cls.Disease object at 0x0000020554E197D0>]
# <cls.Disease object at 0x0000020554E197D0> added to 7 16
# Node health is 1
# Health decreased
# Node health is 2
# Health decreased
# Node health is 3
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554DFBA50>] [<cls.Disease object at 0x0000020554DFBA50>]
# [<cls.Disease object at 0x0000020554DFBA50>]
# <cls.Disease object at 0x0000020554DFBA50> added to 14 8
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554DFBA50>] [<cls.Disease object at 0x0000020554DFBA50>]
# Adding from [<cls.Disease object at 0x0000020554DFBA50>] [<cls.Disease object at 0x0000020554DFBA50>]
# Health decreased
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554DFBB10>] [<cls.Disease object at 0x0000020554DFBB10>]
# Health decreased
# Node health is 2
# Node health is 1
# Adding from [<cls.Disease object at 0x00000205544EA690>] [<cls.Disease object at 0x00000205544EA690>]
# [<cls.Disease object at 0x0000020551F74090>]
# <cls.Disease object at 0x00000205544EA690> added to 15 10
# Adding from [<cls.Disease object at 0x00000205544EA690>] [<cls.Disease object at 0x00000205544EA690>]
# <cls.Disease object at 0x00000205544EA690> added to 15 12
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020551F74090>] [<cls.Disease object at 0x0000020551F74090>]
# [<cls.Disease object at 0x0000020551F74090>]
# <cls.Disease object at 0x0000020551F74090> added to 11 7
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x00000205544EA690>] [<cls.Disease object at 0x00000205544EA690>]
# [<cls.Disease object at 0x00000205544EA690>]
# <cls.Disease object at 0x00000205544EA690> added to 9 16
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020551F74090>] [<cls.Disease object at 0x0000020551F74090>]
# [<cls.Disease object at 0x0000020551F74090>]
# <cls.Disease object at 0x0000020551F74090> added to 14 8
# Node health is 7
# Adding from [<cls.Disease object at 0x0000020551F74090>] [<cls.Disease object at 0x0000020551F74090>]
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020551F74090>] [<cls.Disease object at 0x0000020551F74090>]
# Adding from [<cls.Disease object at 0x0000020551F74090>] [<cls.Disease object at 0x0000020551F74090>]
# Node health is 5
# Node health is 6
# Adding from [<cls.Disease object at 0x00000205544EA690>] [<cls.Disease object at 0x00000205544EA690>]
# Node health is 0
# Node died
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020551F74090>] [<cls.Disease object at 0x0000020551F74090>]
# Node health is 4
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020551F74090>] [<cls.Disease object at 0x0000020551F74090>]
# [<cls.Disease object at 0x00000205544EA690>]
# <cls.Disease object at 0x0000020551F74090> added to 10 8
# Node health is 2
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554DDC690>] [<cls.Disease object at 0x0000020554DDC690>]
# <cls.Disease object at 0x0000020554DDC690> added to 14 18
# Node health is 2
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x00000205544EA690>] [<cls.Disease object at 0x00000205544EA690>]
# [<cls.Disease object at 0x0000020554DDC690>]
# <cls.Disease object at 0x00000205544EA690> added to 12 16
# Node health is 3
# Node health is 6
# Adding from [<cls.Disease object at 0x0000020551F74090>] [<cls.Disease object at 0x0000020551F74090>]
# [<cls.Disease object at 0x0000020551F74090>]
# <cls.Disease object at 0x0000020551F74090> added to 7 6
# Adding from [<cls.Disease object at 0x0000020551F74090>] [<cls.Disease object at 0x0000020551F74090>]
# <cls.Disease object at 0x0000020551F74090> added to 7 7
# Node health is 6
# Adding from [<cls.Disease object at 0x0000020554CBF450>] [<cls.Disease object at 0x0000020554CBF450>]
# [<cls.Disease object at 0x0000020554CBF450>]
# <cls.Disease object at 0x0000020554CBF450> added to 7 6
# Node health is 2
# Node health is 3
# Health decreased
# Node health is 6
# Adding from [<cls.Disease object at 0x0000020554D6C390>] [<cls.Disease object at 0x0000020554D6C390>]
# [<cls.Disease object at 0x0000020554D6C390>]
# <cls.Disease object at 0x0000020554D6C390> added to 13 11
# Adding from [<cls.Disease object at 0x0000020554D6C390>] [<cls.Disease object at 0x0000020554D6C390>]
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554CBF450>] [<cls.Disease object at 0x0000020554CBF450>]
# Health decreased
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554CBF450>] [<cls.Disease object at 0x0000020554CBF450>]
# [<cls.Disease object at 0x0000020554CBF450>]
# <cls.Disease object at 0x0000020554CBF450> added to 7 6
# Adding from [<cls.Disease object at 0x0000020554CBF450>] [<cls.Disease object at 0x0000020554CBF450>]
# <cls.Disease object at 0x0000020554CBF450> added to 8 4
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554CBF450>] [<cls.Disease object at 0x0000020554CBF450>]
# Node health is 7
# Adding from [<cls.Disease object at 0x0000020554CBF450>] [<cls.Disease object at 0x0000020554CBF450>]
# [<cls.Disease object at 0x0000020554CBF450>]
# <cls.Disease object at 0x0000020554CBF450> added to 8 5
# Node health is 6
# Adding from [<cls.Disease object at 0x0000020554D6C390>] [<cls.Disease object at 0x0000020554D6C390>]
# [<cls.Disease object at 0x0000020554CBF450>]
# <cls.Disease object at 0x0000020554D6C390> added to 9 8
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554CBF450>] [<cls.Disease object at 0x0000020554CBF450>]
# [<cls.Disease object at 0x0000020554D6C390>]
# <cls.Disease object at 0x0000020554CBF450> added to 13 11
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554D6C390>] [<cls.Disease object at 0x0000020554D6C390>]
# Adding from [<cls.Disease object at 0x0000020554D6C390>] [<cls.Disease object at 0x0000020554D6C390>]
# Health decreased
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554CBF450>] [<cls.Disease object at 0x0000020554CBF450>]
# [<cls.Disease object at 0x0000020554CBF450>]
# <cls.Disease object at 0x0000020554CBF450> added to 15 3
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554CBF450>] [<cls.Disease object at 0x0000020554CBF450>]
# [<cls.Disease object at 0x0000020554CBF450>]
# <cls.Disease object at 0x0000020554CBF450> added to 13 6
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554CBF450>] [<cls.Disease object at 0x0000020554CBF450>]
# [<cls.Disease object at 0x0000020554CBF450>]
# <cls.Disease object at 0x0000020554CBF450> added to 13 7
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554CBF450>] [<cls.Disease object at 0x0000020554CBF450>]
# Node health is 2
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554D6C390>] [<cls.Disease object at 0x0000020554D6C390>]
# Adding from [<cls.Disease object at 0x0000020554D6C390>] [<cls.Disease object at 0x0000020554D6C390>]
# [<cls.Disease object at 0x0000020554CBF450>]
# <cls.Disease object at 0x0000020554D6C390> added to 14 11
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554D56950>] [<cls.Disease object at 0x0000020554D56950>]
# [<cls.Disease object at 0x0000020554D6C390>]
# <cls.Disease object at 0x0000020554D56950> added to 9 15
# Node health is 5
# Node health is 5
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554D6C390>] [<cls.Disease object at 0x0000020554D6C390>]
# [<cls.Disease object at 0x0000020554D6C390>]
# <cls.Disease object at 0x0000020554D6C390> added to 9 16
# Node health is 5
# Node health is 2
# Node health is 6
# Health decreased
# Node health is 3
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554D86990>] [<cls.Disease object at 0x0000020554D86990>]
# [<cls.Disease object at 0x0000020554D86990>]
# <cls.Disease object at 0x0000020554D86990> added to 12 6
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554C7C610>] [<cls.Disease object at 0x0000020554C7C610>]
# [<cls.Disease object at 0x0000020554D86990>]
# <cls.Disease object at 0x0000020554C7C610> added to 14 11
# Health decreased
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554D86990>] [<cls.Disease object at 0x0000020554D86990>]
# [<cls.Disease object at 0x0000020554D86990>]
# <cls.Disease object at 0x0000020554D86990> added to 15 4
# Health decreased
# Node health is 1
# Node health is 7
# Node health is 2
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554D86990>] [<cls.Disease object at 0x0000020554D86990>]
# Adding from [<cls.Disease object at 0x0000020554D86990>] [<cls.Disease object at 0x0000020554D86990>]
# [<cls.Disease object at 0x0000020554C7C610>]
# <cls.Disease object at 0x0000020554D86990> added to 14 10
# Health decreased
# Node health is 1
# Health decreased
# Node health is 2
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554D86990>] [<cls.Disease object at 0x0000020554D86990>]
# <cls.Disease object at 0x0000020554D86990> added to 9 4
# Node health is 3
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554D86990>] [<cls.Disease object at 0x0000020554D86990>]
# [<cls.Disease object at 0x0000020554D86990>]
# <cls.Disease object at 0x0000020554D86990> added to 9 8
# Adding from [<cls.Disease object at 0x0000020554D86990>] [<cls.Disease object at 0x0000020554D86990>]
# Health decreased
# Node health is 5
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554D86990>] [<cls.Disease object at 0x0000020554D86990>]
# [<cls.Disease object at 0x0000020554D86990>]
# <cls.Disease object at 0x0000020554D86990> added to 9 4
# Node health is 6
# Node health is 4
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554D86990>] [<cls.Disease object at 0x0000020554D86990>]
# [<cls.Disease object at 0x0000020554D86990>]
# <cls.Disease object at 0x0000020554D86990> added to 14 3
# Node health is 5
# Node health is 3
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554C394D0>] [<cls.Disease object at 0x0000020554C394D0>]
# [<cls.Disease object at 0x0000020554C394D0>]
# <cls.Disease object at 0x0000020554C394D0> added to 14 5
# Node health is 0
# Node died
# Node health is 7
# Adding from [<cls.Disease object at 0x0000020554C394D0>] [<cls.Disease object at 0x0000020554C394D0>]
# [<cls.Disease object at 0x0000020554DCF690>]
# <cls.Disease object at 0x0000020554C394D0> added to 10 8
# Node health is 2
# Node health is 6
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554DE4750>] [<cls.Disease object at 0x0000020554DE4750>]
# <cls.Disease object at 0x0000020554DE4750> added to 9 19
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554C394D0>] [<cls.Disease object at 0x0000020554C394D0>]
# [<cls.Disease object at 0x0000020554C394D0>]
# <cls.Disease object at 0x0000020554C394D0> added to 9 7
# Adding from [<cls.Disease object at 0x0000020554C394D0>] [<cls.Disease object at 0x0000020554C394D0>]
# [<cls.Disease object at 0x0000020554C394D0>]
# <cls.Disease object at 0x0000020554C394D0> added to 10 5
# Health decreased
# Node health is 5
# Node health is 1
# Node health is 2
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554DCF690>] [<cls.Disease object at 0x0000020554DCF690>]
# [<cls.Disease object at 0x0000020554DE4750>]
# <cls.Disease object at 0x0000020554DCF690> added to 10 14
# Health decreased
# Node health is 1
# Node health is 6
# Adding from [<cls.Disease object at 0x0000020554DCF690>] [<cls.Disease object at 0x0000020554DCF690>]
# Node health is 5
# Node health is 1
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554DCF690>] [<cls.Disease object at 0x0000020554DCF690>]
# [<cls.Disease object at 0x0000020554DCF690>]
# <cls.Disease object at 0x0000020554DCF690> added to 14 10
# Adding from [<cls.Disease object at 0x0000020554DCF690>] [<cls.Disease object at 0x0000020554DCF690>]
# [<cls.Disease object at 0x0000020554C394D0>]
# <cls.Disease object at 0x0000020554DCF690> added to 15 10
# Node health is 5
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554C394D0>] [<cls.Disease object at 0x0000020554C394D0>]
# [<cls.Disease object at 0x0000020554C394D0>]
# <cls.Disease object at 0x0000020554C394D0> added to 15 4
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554DCF690>] [<cls.Disease object at 0x0000020554DCF690>]
# [<cls.Disease object at 0x0000020554C394D0>]
# <cls.Disease object at 0x0000020554DCF690> added to 15 10
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554C394D0>] [<cls.Disease object at 0x0000020554C394D0>]
# [<cls.Disease object at 0x0000020554DCF690>]
# <cls.Disease object at 0x0000020554C394D0> added to 15 11
# Health decreased
# Node health is 1
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554DCF690>] [<cls.Disease object at 0x0000020554DCF690>]
# [<cls.Disease object at 0x0000020554DE4750>]
# <cls.Disease object at 0x0000020554DCF690> added to 10 14
# Health decreased
# Node health is 5
# Health decreased
# Node health is 2
# Health decreased
# Node health is 5
# Node health is 1
# Node health is 5
# Health decreased
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554D580D0>] [<cls.Disease object at 0x0000020554D580D0>]
# [<cls.Disease object at 0x0000020554D01010>]
# <cls.Disease object at 0x0000020554D580D0> added to 9 13
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554D01010>] [<cls.Disease object at 0x0000020554D01010>]
# [<cls.Disease object at 0x0000020554D01010>]
# <cls.Disease object at 0x0000020554D01010> added to 15 11
# Node health is 0
# Node died
# Health decreased
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554C70410>] [<cls.Disease object at 0x0000020554C70410>]
# [<cls.Disease object at 0x0000020554C70410>]
# <cls.Disease object at 0x0000020554C70410> added to 13 5
# Node health is 1
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554C70410>] [<cls.Disease object at 0x0000020554C70410>]
# [<cls.Disease object at 0x0000020554C70410>]
# <cls.Disease object at 0x0000020554C70410> added to 12 5
# Node health is 5
# Node health is 1
# Health decreased
# Node health is 2
# Node health is 5
# Health decreased
# Node health is 3
# Node health is 7
# Adding from [<cls.Disease object at 0x0000020554C70410>] [<cls.Disease object at 0x0000020554C70410>]
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554C70410>] [<cls.Disease object at 0x0000020554C70410>]
# [<cls.Disease object at 0x0000020554C70410>]
# <cls.Disease object at 0x0000020554C70410> added to 10 4
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554C70410>] [<cls.Disease object at 0x0000020554C70410>]
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554C70410>] [<cls.Disease object at 0x0000020554C70410>]
# [<cls.Disease object at 0x0000020554C70410>]
# <cls.Disease object at 0x0000020554C70410> added to 14 4
# Health decreased
# Node health is 2
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554C70410>] [<cls.Disease object at 0x0000020554C70410>]
# [<cls.Disease object at 0x0000020554D01010>]
# <cls.Disease object at 0x0000020554C70410> added to 14 10
# Health decreased
# Node health is 2
# Health decreased
# Node health is 4
# Health decreased
# Node health is 1
# Node health is 5
# Health decreased
# Node health is 4
# Node health is 5
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554E84390>] [<cls.Disease object at 0x0000020554E84390>]
# [<cls.Disease object at 0x0000020554E84390>]
# <cls.Disease object at 0x0000020554E84390> added to 14 8
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554E84390>] [<cls.Disease object at 0x0000020554E84390>]
# [<cls.Disease object at 0x0000020554E84390>]
# <cls.Disease object at 0x0000020554E84390> added to 14 4
# Adding from [<cls.Disease object at 0x0000020554E84390>] [<cls.Disease object at 0x0000020554E84390>]
# [<cls.Disease object at 0x0000020554E84390>]
# <cls.Disease object at 0x0000020554E84390> added to 14 6
# Node health is 0
# Node died
# Health decreased
# Node health is 1
# Health decreased
# Node health is 6
# Node health is 0
# Node died
# Node health is 3
# Node health is 2
# Node health is 1
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554E84390>] [<cls.Disease object at 0x0000020554E84390>]
# Node health is 4
# Node health is 0
# Node died
# Node health is 5
# Health decreased
# Node health is 4
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554E84390>] [<cls.Disease object at 0x0000020554E84390>]
# [<cls.Disease object at 0x0000020554E84390>]
# <cls.Disease object at 0x0000020554E84390> added to 15 5
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554E05E90>] [<cls.Disease object at 0x0000020554E05E90>]
# [<cls.Disease object at 0x0000020554E3B110>]
# <cls.Disease object at 0x0000020554E05E90> added to 9 13
# Health decreased
# Node health is 1
# Health decreased
# Node health is 4
# Node health is 0
# Node died
# Node health is 0
# Node died
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554DFAFD0>] [<cls.Disease object at 0x0000020554DFAFD0>]
# [<cls.Disease object at 0x0000020554D2C250>]
# <cls.Disease object at 0x0000020554DFAFD0> added to 9 16
# Adding from [<cls.Disease object at 0x0000020554DFAFD0>] [<cls.Disease object at 0x0000020554DFAFD0>]
# [<cls.Disease object at 0x0000020554D2C250>]
# <cls.Disease object at 0x0000020554DFAFD0> added to 10 14
# Health decreased
# Node health is 1
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554DF8810>] [<cls.Disease object at 0x0000020554DF8810>]
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554DF8810>] [<cls.Disease object at 0x0000020554DF8810>]
# Health decreased
# Node health is 3
# Node health is 3
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554DF8810>] [<cls.Disease object at 0x0000020554DF8810>]
# [<cls.Disease object at 0x0000020554DF8810>]
# <cls.Disease object at 0x0000020554DF8810> added to 12 4
# Node health is 5
# Node health is 0
# Node died
# Health decreased
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554DF8810>] [<cls.Disease object at 0x0000020554DF8810>]
# [<cls.Disease object at 0x0000020554DF8810>]
# <cls.Disease object at 0x0000020554DF8810> added to 14 5
# Node health is 0
# Node died
# Node health is 4
# Node health is 4
# Node health is 6
# Node health is 0
# Node died
# Node health is 2
# Health decreased
# Node health is 3
# Health decreased
# Node health is 1
# Node health is 3
# Node health is 1
# Node health is 4
# Node health is 1
# Node health is 1
# Health decreased
# Node health is 3
# Node health is 3
# Node health is 5
# Node health is 6
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554D6CE90>] [<cls.Disease object at 0x0000020554D6CE90>]
# <cls.Disease object at 0x0000020554D6CE90> added to 16 18
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020552999450>] [<cls.Disease object at 0x0000020552999450>]
# [<cls.Disease object at 0x0000020552999450>]
# <cls.Disease object at 0x0000020552999450> added to 9 9
# Health decreased
# Node health is 2
# Node health is 4
# Node health is 1
# Node health is 0
# Node died
# Node health is 0
# Node died
# Node health is 3
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554E1E310>] [<cls.Disease object at 0x0000020554E1E310>]
# [<cls.Disease object at 0x0000020554E1E310>]
# <cls.Disease object at 0x0000020554E1E310> added to 16 18
# Node health is 1
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554EA4B10>] [<cls.Disease object at 0x0000020554EA4B10>]
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554E1F810>] [<cls.Disease object at 0x0000020554E1F810>]
# Health decreased
# Node health is 1
# Node health is 3
# Health decreased
# Node health is 4
# Health decreased
# Node health is 5
# Node health is 0
# Node died
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554E1E310>] [<cls.Disease object at 0x0000020554E1E310>]
# Adding from [<cls.Disease object at 0x0000020554E1E310>] [<cls.Disease object at 0x0000020554E1E310>]
# <cls.Disease object at 0x0000020554E1E310> added to 16 17
# Health decreased
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554EA6F10>] [<cls.Disease object at 0x0000020554EA6F10>]
# Health decreased
# Node health is 5
# Adding from [<cls.Disease object at 0x0000020554EA7850>] [<cls.Disease object at 0x0000020554EA7850>]
# Node health is 3
# Health decreased
# Node health is 4
# Node health is 1
# Node health is 4
# Node health is 1
# Health decreased
# Node health is 2
# Health decreased
# Node health is 1
# Node health is 1
# Health decreased
# Node health is 1
# Node health is 4
# Health decreased
# Node health is 4
# Adding from [<cls.Disease object at 0x0000020554EA6F10>] [<cls.Disease object at 0x0000020554EA6F10>]
# Adding from [<cls.Disease object at 0x0000020554EA6F10>] [<cls.Disease object at 0x0000020554EA6F10>]
# [<cls.Disease object at 0x0000020554EA6F10>]
# <cls.Disease object at 0x0000020554EA6F10> added to 13 5
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554EF0450>] [<cls.Disease object at 0x0000020554EF0450>]
# [<cls.Disease object at 0x0000020554EF0450>]
# <cls.Disease object at 0x0000020554EF0450> added to 13 5
# Node health is 0
# Node died
# Node health is 1
# Health decreased
# Node health is 3
# Health decreased
# Node health is 3
# Node health is 1
# Node health is 0
# Node died
# Health decreased
# Node health is 4
# Node health is 1
# Node health is 1
# Node health is 2
# Node health is 3
# Health decreased
# Node health is 3
# Node health is 4
# Node health is 1
# Node health is 1
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554ECA890>] [<cls.Disease object at 0x0000020554ECA890>]
# [<cls.Disease object at 0x0000020554ECA890>]
# <cls.Disease object at 0x0000020554ECA890> added to 12 19
# Health decreased
# Node health is 2
# Health decreased
# Node health is 2
# Adding from [<cls.Disease object at 0x0000020554ECA910>] [<cls.Disease object at 0x0000020554ECA910>]
# Health decreased
# Node health is 2
# Health decreased
# Node health is 2
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554ECA910>] [<cls.Disease object at 0x0000020554ECA910>]
# [<cls.Disease object at 0x0000020554ECA910>]
# <cls.Disease object at 0x0000020554ECA910> added to 12 6
# Health decreased
# Node health is 2
# Health decreased
# Node health is 1
# Node health is 1
# Node health is 2
# Health decreased
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554F33F50>] [<cls.Disease object at 0x0000020554F33F50>]
# [<cls.Disease object at 0x0000020554F33F50>]
# <cls.Disease object at 0x0000020554F33F50> added to 10 19
# Health decreased
# Node health is 1
# Node health is 4
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554F33F50>] [<cls.Disease object at 0x0000020554F33F50>]
# [<cls.Disease object at 0x0000020554F33F50>]
# <cls.Disease object at 0x0000020554F33F50> added to 11 20
# Node health is 2
# Node health is 1
# Node health is 1
# Node health is 1
# Health decreased
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 2
# Health decreased
# Node health is 1
# Node health is 1
# Node health is 1
# Health decreased
# Node health is 3
# Node health is 1
# Node health is 1
# Health decreased
# Node health is 1
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554F33E90>] [<cls.Disease object at 0x0000020554F33E90>]
# [<cls.Disease object at 0x0000020554F33E90>]
# <cls.Disease object at 0x0000020554F33E90> added to 18 18
# Node health is 1
# Node health is 1
# Node health is 3
# Node health is 0
# Node died
# Node health is 0
# Node died
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 0
# Node died
# Node health is 1
# Node health is 1
# Node health is 3
# Node health is 1
# Health decreased
# Node health is 2
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Adding from [<cls.Disease object at 0x0000020554E9AC90>] [<cls.Disease object at 0x0000020554E9AC90>]
# Node health is 1
# Node health is 2
# Node health is 1
# Node health is 1
# Node health is 0
# Node died
# Node health is 2
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Health decreased
# Node health is 1
# Node health is 1
# Node health is 0
# Node died
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 1
# Node health is 0
# Node died
# Node health is 1
# Node health is 0
# Node died
# Node health is 0
# Node died
# Node health is 0
# Node died
# Node health is 0
# Node died
# Node health is 0
# Node died

# %%
# print("Metrics",sim.all_metrics[0].metrics,sim.metrics.get_iterations())
sim.end()
# Out:
# Metrics dead:[] , num_healed:0 , iterations:2 , start_count:36 , initial_hotspots:[[14, 13], [15, 5], [9, 13]] , starting_map:<cls.Map object at 0x0000020552FA7E50> ,  30
# Ended because of: Condition.NO_INFECTED
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 2
#       1 print("Metrics",sim.all_metrics[0].metrics,sim.metrics.get_iterations())
# ----> 2 sim.end()
#
# File c:\Users\tyran\Documents\Uni\2024S2\CITS4403\CITS4403_Project\cls.py:534, in Simulation.end(self)
#     529 # print("Started at:")
#     530 # self.view(chosen_map=self.metrics.get_first_map())
#     531 # print("Finished at:")
#     532 # self.view()
#     533 for met in self.all_metrics:
# --> 534     it = met.get_iterations
#     535     print(it,str(met))
#
# AttributeError: 'StepMetrics' object has no attribute 'get_iterations'

# %%
sim.view()
sim.step()
sim.view()
# Out:
# Moving 13 1
# Moving 10 19
# Moving 16 6
# Moving 11 12
# Moving 4 2
# Moving 14 7
# Moving 21 13
# Moving 21 7
# Moving 0 15
# Moving 17 19
# Moving 11 9
# Moving 13 7
# Moving 9 17
# Moving 23 16
# Moving 13 3
# Moving 15 1
# Moving 15 9
# Moving 9 18
# Moving 3 9
# Moving 3 23
# Moving 10 4
# Moving 7 0
# Moving 0 23
# Moving 22 19
# Moving 19 10
# Moving 21 24
# Moving 15 8
# Moving 17 7
# Moving 9 8
# Moving 9 14
# Moving 3 15
# Moving 8 21
# Moving 1 7
# Moving 18 18
# Moving 22 11
# Moving 12 13
# Moving 2 24
# Moving 1 16
# Moving 15 10
# Moving 15 13
# Moving 22 9
# Moving 4 24
# Moving 8 18
# Moving 10 13
# Moving 20 20
# Moving 6 23
# Moving 1 2
# Moving 22 8
# Moving 3 17
# Moving 10 20
# Moving 19 23
# Moving 4 21
# Moving 4 15
# Moving 24 16
# Moving 7 21
# Moving 17 18
# Moving 2 13
# Moving 6 22
# Moving 21 3
# Moving 0 12
# Moving 0 21
# Moving 14 23
# Moving 14 5
# Moving 4 7
# Moving 14 6
# Health decreased
# Node health is 3
# Adding from [<cls.Disease object at 0x0000020554D46AD0>] [<cls.Disease object at 0x0000020554D46AD0>]
# <cls.Disease object at 0x0000020554D46AD0> added to 15 7
# Moving 5 14
# Moving 16 12
# Moving 12 7
# Moving 24 5
# Moving 24 13
# Moving 7 1
# Moving 2 10
# Moving 23 7
# Moving 9 21
# Moving 16 16
# Moving 5 3
# Moving 1 17
# Moving 23 14
# Moving 20 5
# Moving 8 22
# Moving 13 19
# Moving 7 18
# Moving 17 24
# Moving 14 10
# Moving 16 0
# Moving 13 5
# Moving 5 8
# Moving 1 8
# Moving 9 6
# Moving 24 21
# Moving 8 17
# Moving 8 4
# Moving 1 13
# Moving 15 5
# Moving 12 14
# Moving 3 24
# Moving 20 6
# Moving 15 12
# Moving 10 24
# Moving 2 11
# Moving 21 1
# Moving 3 1
# Moving 5 11
# Moving 17 6
# Moving 7 6
# Moving 4 12
# Moving 21 2
# Moving 11 24
# Moving 5 23
# Moving 9 4
# Moving 19 19
# Moving 13 16
# Moving 11 20
# Moving 4 10
# Moving 22 14
# Moving 12 2
# Moving 17 21
# Moving 20 9
# Moving 0 14
# Moving 2 9
# Moving 2 19
# Moving 15 23
# Moving 16 13
# Moving 12 17
# Moving 19 2
# Moving 5 6
# Moving 23 11
# Moving 19 14
# Moving 20 0
# Moving 21 14
# Moving 18 5
# Moving 7 8
# Moving 10 17
# Moving 22 21
# Moving 19 18
# Moving 11 10
# Moving 8 10
# Moving 10 12
# Health decreased
# Node health is 3
# Moving 21 0
# Moving 1 21
# Moving 5 5
